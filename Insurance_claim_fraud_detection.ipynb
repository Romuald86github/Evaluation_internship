# %%
# !pwd
# Out:
# /content

# %%
cd/content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pickle

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
# Drop unnecessary columns
df = df.drop(['policy_number', '_c39'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_bind_date             1000 non-null   object
#  3   policy_state                 1000 non-null   object
#  4   policy_csl                   1000 non-null   object
#  5   policy_deductable            1000 non-null   int64
#  6   policy_annual_premium        1000 non-null   float64
#  7   umbrella_limit               1000 non-null   int64
#  8   insured_zip                  1000 non-null   int64
#  9   insured_sex                  1000 non-null   object
#  10  insured_education_level      1000 non-null   object
#  11  insured_occupation           1000 non-null   object
#  12  insured_hobbies              1000 non-null   object
# ...

# %% [markdown]
# there is no missing value

# %%
# Feature Engineering (extracting year, month, day from incident_date)
df['incident_year'] = pd.to_datetime(df['incident_date']).dt.year
df['incident_month'] = pd.to_datetime(df['incident_date']).dt.month
df['incident_day'] = pd.to_datetime(df['incident_date']).dt.day
df = df.drop('incident_date', axis=1)

# %%
# dropping unnecessary dates

df.drop('policy_bind_date', axis = 1, inplace = True)

# %%
for i in df.columns:
  print(df[i].value_counts())
# Out:
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: months_as_customer, Length: 391, dtype: int64
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: age, dtype: int64
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64
# 1000    351
# 500     342
# 2000    307
# Name: policy_deductable, dtype: int64
# 1558.29    2
# 1215.36    2
# 1362.87    2
# ...

# %% [markdown]
# - convert policy deductable into object
# - umbrela limit to be removed: filled with 0 values
# - capital gain and loss to be removed: filled with 0 values
# - collision_type contains '?'. let's locate them and replace by the mode or remove the column
# - convert number of vehcles involved into categoical
# - property_damage contains '?'. let's locate them and replace by the mode or remove the column
# - convert bodily_injuries into categorical
# - convert witnesses into categorical
# - police_report_available contains '?'. let's locate them and replace by the mode or remove the column

# %%
list(df.columns)
# Out:
# ['months_as_customer',
#  'age',
#  'policy_state',
#  'policy_csl',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'capital-gains',
#  'capital-loss',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'property_damage',
#  'bodily_injuries',
#  'witnesses',
#  'police_report_available',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'fraud_reported',
#  'incident_year',
#  'incident_month',
#  'incident_day']

# %%
df['policy_deductable'] = df['policy_deductable'].astype(object)

# %%
df.drop(['umbrella_limit','capital-gains','capital-loss'], axis = 1, inplace = True)

# %%
df.loc[df['collision_type']=='?',]
# Out:
#      months_as_customer  age policy_state policy_csl policy_deductable  \
# 1                   228   42           IN    250/500              2000
# 4                   228   44           IL   500/1000              1000
# 13                  121   34           OH    100/300              1000
# 26                  257   43           IN    100/300              2000
# 27                  202   34           IN    100/300               500
# ..                  ...  ...          ...        ...               ...
# 964                 163   37           IN   500/1000              1000
# 969                 398   55           OH    250/500               500
# 983                  17   39           IL    250/500              1000
# 994                 141   30           IN   500/1000              1000
# 999                 456   60           OH    250/500              1000
#
#      policy_annual_premium  insured_zip insured_sex insured_education_level  \
# ...

# %%
df['collision_type'].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %% [markdown]
# removing the rows with '?' will cause a severe data loss. the mode is not dominant. So, we will remove the column

# %%
df.drop('collision_type', axis = 1, inplace = True)

# %%
df.loc[df['property_damage']=='?',]
# Out:
#      months_as_customer  age policy_state policy_csl policy_deductable  \
# 1                   228   42           IN    250/500              2000
# 3                   256   41           IL    250/500              2000
# 6                   137   34           IN    250/500              1000
# 7                   165   37           IL    100/300              1000
# 16                   70   26           OH   500/1000              1000
# ..                  ...  ...          ...        ...               ...
# 993                 124   28           OH    250/500              1000
# 994                 141   30           IN   500/1000              1000
# 997                 130   34           OH    250/500               500
# 998                 458   62           IL   500/1000              2000
# 999                 456   60           OH    250/500              1000
#
#      policy_annual_premium  insured_zip insured_sex insured_education_level  \
# ...

# %%
df['property_damage'].value_counts()
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %% [markdown]
# '?' has the highest number of unique values. we will drop the column

# %%
df.drop('property_damage', axis =1, inplace = True)

# %%
df['bodily_injuries'] = df['bodily_injuries'].astype(object)

# %%
df['witnesses'] = df['witnesses'].astype(object)

# %%
df.loc[df['police_report_available']=='?',]
# Out:
#      months_as_customer  age policy_state policy_csl policy_deductable  \
# 1                   228   42           IN    250/500              2000
# 6                   137   34           IN    250/500              1000
# 9                   212   42           IL    100/300               500
# 10                  235   42           OH    100/300               500
# 20                  460   62           IN    250/500              1000
# ..                  ...  ...          ...        ...               ...
# 989                  22   21           IN    250/500              1000
# 993                 124   28           OH    250/500              1000
# 995                   3   38           OH   500/1000              1000
# 996                 285   41           IL    100/300              1000
# 999                 456   60           OH    250/500              1000
#
#      policy_annual_premium  insured_zip insured_sex insured_education_level  \
# ...

# %%
df['police_report_available'].value_counts()
# Out:
# ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %% [markdown]
# '?' is a mode. we will drop the column.

# %%
df.drop('police_report_available', axis =1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_state                 1000 non-null   object
#  3   policy_csl                   1000 non-null   object
#  4   policy_deductable            1000 non-null   object
#  5   policy_annual_premium        1000 non-null   float64
#  6   insured_zip                  1000 non-null   int64
#  7   insured_sex                  1000 non-null   object
#  8   insured_education_level      1000 non-null   object
#  9   insured_occupation           1000 non-null   object
#  10  insured_hobbies              1000 non-null   object
#  11  insured_relationship         1000 non-null   object
#  12  incident_type                1000 non-null   object
# ...

# %%
# encoding categorical colmns
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

for column in df:
    if df[column].dtypes == 'object':
        df[column] = encoder.fit_transform(df[column].values.reshape(-1,1))


df
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48           2.0         1.0                1.0
# 1                   228   42           1.0         1.0                2.0
# 2                   134   29           2.0         0.0                2.0
# 3                   256   41           0.0         1.0                2.0
# 4                   228   44           0.0         2.0                1.0
# ..                  ...  ...           ...         ...                ...
# 995                   3   38           2.0         2.0                1.0
# 996                 285   41           0.0         0.0                1.0
# 997                 130   34           2.0         1.0                0.0
# 998                 458   62           0.0         2.0                2.0
# 999                 456   60           2.0         1.0                1.0
#
#      policy_annual_premium  insured_zip  insured_sex  insured_education_level  \
# ...

# %%
# modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import RandomOverSampler

# %%
# Split the Data
X = df.drop('fraud_reported', axis=1)
y = df['fraud_reported']

# %%
# Select features using RandomForestClassifier feature importance
selector = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=42), threshold='median')
X = selector.fit_transform(X, y)

# %%
# Oversample the minority class using RandomOverSampler
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X, y)

# %%
# Split the data after feature selection
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# Standardize numerical features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Build a neural network
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 2s 16ms/step - loss: 0.7505 - accuracy: 0.5296 - val_loss: 0.6676 - val_accuracy: 0.6307
# Epoch 2/10
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.5587 - val_loss: 0.6381 - val_accuracy: 0.6556
# Epoch 3/10
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7033 - accuracy: 0.5607 - val_loss: 0.6190 - val_accuracy: 0.7012
# Epoch 4/10
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6495 - accuracy: 0.6314 - val_loss: 0.6044 - val_accuracy: 0.7178
# Epoch 5/10
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6301 - accuracy: 0.6303 - val_loss: 0.5866 - val_accuracy: 0.7303
# Epoch 6/10
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6158 - accuracy: 0.6708 - val_loss: 0.5738 - val_accuracy: 0.7344
# Epoch 7/10
# ...

# %%
"""If the model's predicted probability for a particular instance is greater than 0.5,
it is assigned to the positive class; otherwise, it is assigned to the negative class."""

# %%
# Evaluate the model
y_pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7350993377483444
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.72      0.73      0.72       142
#          1.0       0.75      0.74      0.75       160
#
#     accuracy                           0.74       302
#    macro avg       0.73      0.73      0.73       302
# weighted avg       0.74      0.74      0.74       302
#
#
# Confusion Matrix:
#  [[103  39]
#  [ 41 119]]

# %%
# saving the model

# %%
model.save('Insurance_Claim_Fraud_Detection.h5')

# %%
# comments and recommendations

# %% [markdown]
# - we combined traditional ML with deep learning due to the complexity and high number of variables in the dataset
# - RandomForest was used for features selection because this is binary classification
# - we recommend further building traditional ML using the same data an compare the accuracies.
# - we should continue data analytics to screen in more relevant features in iproving model's accuracy
